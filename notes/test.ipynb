# %% [markdown]
# # Test jupyter notebook file for demo
# - idk just random text`

# %%
print("hello world")
test_variable = "Hello World Test Variable Edition"
print(test_variable)
# Out:
# hello world
# Hello World Test Variable Edition

# %%
print("Secondary test Hi")
# Out:
# Secondary test Hi
